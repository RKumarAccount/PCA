# %% [markdown]
# <a href="https://colab.research.google.com/github/RKumarAccount/PCA/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris

# %%
iris=load_iris()
X=iris.data
y=iris.target

# %%
pca=PCA(n_components=2)
#pca.fit(X)
X_pca=pca.fit_transform(X)

# %%
sns.scatterplot(x=X_pca[:,0],y=X_pca[:,1],hue=y,palette='viridis',s=50)

plt.title('PCA: Iris Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
